# %% [markdown]
# # Covid en Argentina

# %% [markdown]
# Descargamos primero los datos del Ministerio

# %%
# !wget https://sisa.msal.gov.ar/datos/descargas/covid-19/files/Covid19Casos.zip
# !unzip Covid19Casos.zip
# !rm Covid19Casos.zip

# %% [markdown]
# y ahora cargamos los datos del archivo csv en un dataframe de cudf, en la memoria de la GPU

# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('reducido.csv', parse_dates=["fecha_apertura"])
df = pd.read_csv('Covid19Casos.csv', parse_dates=["fecha_apertura"])

# %% [markdown]
# echemos un vistazo...

# %%
df.head(6)
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0         1000000    M  54.0            Años              Argentina
# 1        10000000    F  52.0            Años              Argentina
# 2        10000001    F  22.0            Años              Argentina
# 3        10000002    F  43.0            Años              Argentina
# 4        10000003    F  33.0            Años              Argentina
# 5        10000004    F  32.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                        CABA                SIN ESPECIFICAR
# 1                        CABA                SIN ESPECIFICAR
# 2                Buenos Aires                Lomas de Zamora
# 3                Buenos Aires                     La Matanza
# 4                        CABA                      COMUNA 01
# 5                        CABA                      COMUNA 08
#
#   carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0           Buenos Aires                   NaN     2020-06-01  ...
# 1                   CABA                   NaN     2021-04-08  ...
# 2           Buenos Aires            2021-04-05     2021-04-08  ...
# 3                   CABA                   NaN     2021-04-08  ...
# 4                   CABA                   NaN     2021-04-08  ...
# 5                   CABA                   NaN     2021-04-08  ...
#
#    fecha_fallecimiento asistencia_respiratoria_mecanica carga_provincia_id  \
# 0                  NaN                               NO                  6
# 1                  NaN                               NO                  2
# 2                  NaN                               NO                  6
# 3                  NaN                               NO                  2
# 4                  NaN                               NO                  2
# 5                  NaN                               NO                  2
#
#   origen_financiamiento    clasificacion clasificacion_resumen  \
# 0               Privado  Caso Descartado            Descartado
# 1               Público  Caso Descartado            Descartado
# 2               Público  Caso Descartado            Descartado
# 3               Público  Caso Descartado            Descartado
# 4               Público  Caso Descartado            Descartado
# 5               Público  Caso Descartado            Descartado
#
#   residencia_provincia_id  fecha_diagnostico residencia_departamento_id  \
# 0                       2         2020-06-09                          0
# 1                       2         2021-04-08                          0
# 2                       6         2021-04-08                        490
# 3                       6         2021-04-06                        427
# 4                       2         2021-04-08                          1
# 5                       2         2021-04-06                          8
#
#   ultima_actualizacion
# 0           2021-05-19
# 1           2021-05-19
# 2           2021-05-19
# 3           2021-05-19
# 4           2021-05-19
# 5           2021-05-19
#
# [6 rows x 25 columns]

# %% [markdown]
# averiguemos en numero de casos confirmados, armando para eso el subconjunto del dataframe restringido a los confirmados y contando ocurrencias

# %%
confirmados_df = df[df["clasificacion_resumen"] == "Confirmado"]
print("confirmados: ",confirmados_df["edad"].count())

# %%
Podemos calcular las muertes

# %%
muertes_df = df[df["clasificacion"]=="Caso confirmado por laboratorio - Fallecido"]
print("muertes: ",muertes_df["edad"].count())

# %% [markdown]
# chequiar en los diarios!

# %%
resumen=df.groupby(['clasificacion']).size()
resumen
# Out:
# clasificacion
# Caso Descartado                                                                              6718545
# Caso Invalidado Epidemiologicamente                                                            15099
# Caso con resultado negativo-no conclusivo - Activo                                             45033
# Caso con resultado negativo-no conclusivo - Activo internado                                    8551
# Caso con resultado negativo-no conclusivo - Fallecido                                            268
# Caso con resultado negativo-no conclusivo - No activo                                         460083
# Caso confirmado por criterio clinico-epidemiol¿gico - Activo                                   13031
# Caso confirmado por criterio clínico - epidemiológico -  Activo internado                       5629
# Caso confirmado por criterio clínico-epidemiologico - Fallecido                                 1403
# Caso confirmado por criterio clínico-epidemiológico - No activo (por tiempo de evolución)     293143
# Caso confirmado por laboratorio - Activo                                                      176351
# Caso confirmado por laboratorio - Activo Internado                                            134715
# Caso confirmado por laboratorio - Fallecido                                                    70880
# Caso confirmado por laboratorio - No Activo por criterio de laboratorio                        82459
# Caso confirmado por laboratorio - No activo (por tiempo de evolución)                        2633548
# Caso sospechoso  - Activo -  Sin muestra                                                       16517
# Caso sospechoso  - No Activo -  Muestra no apta                                                 4067
# Caso sospechoso - Activo -  Muestra no apta                                                      135
# Caso sospechoso - Activo - Con muestra sin resultado concluyente                               25983
# Caso sospechoso - Activo Internado - Con muestra sin resultado concluyente                     13171
# Caso sospechoso - Activo Internado - Muestra no apta                                             458
# Caso sospechoso - Activo Internado - Sin muestra                                               15690
# Caso sospechoso - Fallecido - Con muestra sin resultado concluyente                              915
# Caso sospechoso - Fallecido - Muestra no apta                                                     42
# Caso sospechoso - Fallecido - Sin muestra                                                       1518
# Caso sospechoso - No Activo - Con muestra sin resultado concluyente                           184959
# Caso sospechoso - No Activo - Sin muestra                                                     176046
# Otro diagnostico                                                                                5485
# Sin clasificar                                                                                   283
# dtype: int64

# %%
def estado(x):
    if x.find('Fallecido')>0: 
        return "Fallecido"
    elif x.find('confirmado'):
        return "Confirmado"    

df["categoria"]=df.apply(lambda x: estado(x['clasificacion']),axis=1)

# %%
df.head(5)
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0         1000000    M  54.0            Años              Argentina
# 1        10000000    F  52.0            Años              Argentina
# 2        10000001    F  22.0            Años              Argentina
# 3        10000002    F  43.0            Años              Argentina
# 4        10000003    F  33.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                        CABA                SIN ESPECIFICAR
# 1                        CABA                SIN ESPECIFICAR
# 2                Buenos Aires                Lomas de Zamora
# 3                Buenos Aires                     La Matanza
# 4                        CABA                      COMUNA 01
#
#   carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0           Buenos Aires                   NaN     2020-06-01  ...
# 1                   CABA                   NaN     2021-04-08  ...
# 2           Buenos Aires            2021-04-05     2021-04-08  ...
# 3                   CABA                   NaN     2021-04-08  ...
# 4                   CABA                   NaN     2021-04-08  ...
#
#    asistencia_respiratoria_mecanica carga_provincia_id origen_financiamiento  \
# 0                                NO                  6               Privado
# 1                                NO                  2               Público
# 2                                NO                  6               Público
# 3                                NO                  2               Público
# 4                                NO                  2               Público
#
#      clasificacion clasificacion_resumen residencia_provincia_id  \
# 0  Caso Descartado            Descartado                       2
# 1  Caso Descartado            Descartado                       2
# 2  Caso Descartado            Descartado                       6
# 3  Caso Descartado            Descartado                       6
# 4  Caso Descartado            Descartado                       2
#
#   fecha_diagnostico  residencia_departamento_id ultima_actualizacion  \
# 0        2020-06-09                           0           2021-05-19
# 1        2021-04-08                           0           2021-05-19
# 2        2021-04-08                         490           2021-05-19
# 3        2021-04-06                         427           2021-05-19
# 4        2021-04-08                           1           2021-05-19
#
#     categoria
# 0  Confirmado
# 1  Confirmado
# 2  Confirmado
# 3  Confirmado
# 4  Confirmado
#
# [5 rows x 26 columns]

# %%
df.groupby(['categoria']).size()
