# %% [markdown]
# <a href="https://colab.research.google.com/github/droyktton/ICNPG/blob/master/Clases/Clases_cusolver/ICNPG_cusolver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CuSolver

# %%
# %%bash
# rm -rf ICNPG
# git clone https://github.com/droyktton/ICNPG.git
# Out:
# Cloning into 'ICNPG'...

# %%
# %%bash
#
# cp /content/ICNPG/Clases/Clases_cusolver/*.cu .

# %%
# %%bash
#
# nvcc -arch=sm_75 cusolver_demo_DnDsyevj_thrust.cu -lcusolver -o cusolver_demo_thrust
# nvcc -arch=sm_75  cusolver_demo_DnDsyevj.cu -lcusolver -o cusolver_demo_cuda
# nvcc -arch=sm_75  syevd_miniexample_thrust.cu -lcusolver -o cusolver_mini_thrust
# nvcc -arch=sm_75  syevd_miniexample.cu -lcusolver -o cusolver_mini_cuda

# %%
# %%bash
#
# ./cusolver_demo_cuda
# ./cusolver_demo_thrust
# ./cusolver_mini_cuda
# ./cusolver_mini_thrust
# Out:
#  Ssyevd time : 0.136948 sec .
#   after syevd : info_gpu = 0
#  primeros 3 eigenvalues :
#   W [1 ] = -2.582273E+01
#   W [2 ] = -2.566824E+01
#   W [3 ] = -2.563596E+01
#  uso:./cusolver_demo_thrust nfilas
# continuamos con default, nfilas=2048
#  Ssyevd time : 0.122873 sec .
#   after syevd : info_gpu = 0
#  primeros 3 eigenvalues :
#   W[1] = -2.582273E+01
#   W[2] = -2.566824E+01
#   W[3] = -2.563596E+01
#  A = (matlab base-1)
# A(1,1) = 3.500000
# A(1,2) = 0.500000
# A(1,3) = 0.000000
# A(2,1) = 0.500000
# A(2,2) = 3.500000
# A(2,3) = 0.000000
# A(3,1) = 0.000000
# A(3,2) = 0.000000
# A(3,3) = 2.000000
# =====
# after syevd: info_gpu = 0
# eigenvalue = (matlab base-1), ascending order
# W[1] = 2.000000E+00
# W[2] = 3.000000E+00
# W[3] = 4.000000E+00
# V = (matlab base-1)
# V(1,1) = 0.000000
# V(1,2) = 0.707107
# V(1,3) = 0.707107
# V(2,1) = 0.000000
# V(2,2) = -0.707107
# V(2,3) = 0.707107
# V(3,1) = 1.000000
# V(3,2) = 0.000000
# V(3,3) = 0.000000
# =====
# ...
